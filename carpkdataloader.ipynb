# %%
from carpk import Carpk

# %%
from torch.utils.data import DataLoader
from torchvision import transforms

# %%
carpklotdataset = Carpk('D:\ISO\datasets\CARPK_devkit', 'train',transform=transforms.Compose([transforms.ToTensor()]))

# %%
(carpklotdataset[1][0]).size()
# Out:
# torch.Size([3, 720, 1280])

# %%
carpklotdataset[0]
# Out:
# (tensor([[[0.2824, 0.2627, 0.2824,  ..., 0.5843, 0.5922, 0.5922],
#           [0.3569, 0.4118, 0.3804,  ..., 0.5922, 0.5843, 0.5922],
#           [0.3569, 0.3294, 0.2941,  ..., 0.5922, 0.5922, 0.5922],
#           ...,
#           [0.4000, 0.2627, 0.2941,  ..., 0.3647, 0.3686, 0.3686],
#           [0.3098, 0.2941, 0.3647,  ..., 0.3725, 0.3647, 0.3569],
#           [0.2980, 0.3804, 0.2824,  ..., 0.3608, 0.3569, 0.3529]],
#
#          [[0.3529, 0.3333, 0.3529,  ..., 0.5765, 0.5843, 0.5843],
#           [0.4275, 0.4824, 0.4510,  ..., 0.5843, 0.5765, 0.5843],
#           [0.4275, 0.4000, 0.3647,  ..., 0.5843, 0.5843, 0.5843],
#           ...,
#           [0.5059, 0.3686, 0.3961,  ..., 0.3451, 0.3490, 0.3490],
#           [0.4196, 0.4039, 0.4745,  ..., 0.3529, 0.3451, 0.3373],
#           [0.4157, 0.5020, 0.4039,  ..., 0.3412, 0.3373, 0.3333]],
#
#          [[0.2471, 0.2275, 0.2471,  ..., 0.5804, 0.5882, 0.5882],
#           [0.3216, 0.3765, 0.3451,  ..., 0.5882, 0.5804, 0.5882],
# ...
